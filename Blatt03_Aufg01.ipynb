# %% [markdown]
# Importiere die Bibliotheken

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread

# %% [markdown]
# Funktion showImg

# %%
def showImg(img, vmin, vmax):
    return plt.imshow(img,cmap="gray", vmin=vmin,vmax=vmax)

# %% [markdown]
# Lade die benötigten Bilder

# %%
Red1=imread("./landsat/bands1/band3.png")
NIR1=imread("./landsat/bands1/band4.png")
SWIR1=imread("./landsat/bands1/band7.png")

Red2=imread("./landsat/bands2/band3.png")
NIR2=imread("./landsat/bands2/band4.png")
SWIR2=imread("./landsat/bands2/band7.png")

Red3=imread("./landsat/bands3/band3.png")
NIR3=imread("./landsat/bands3/band4.png")
SWIR3=imread("./landsat/bands3/band7.png")

# %% [markdown]
# die NDVI Funktion

# %%
def NDVI(Red,NIR):
    Red=Red.astype(int)
    NIR=NIR.astype(int)
    NDVI=(NIR-Red)/(NIR+Red)
    return showImg(NDVI, -1,1)

# %%
NDVI(Red1,NIR1)

# %%
NDVI(Red2,NIR2)

# %%
NDVI(Red3,NIR3)

# %% [markdown]
# die NDWI-Funktion

# %%
def NDWI(NIR,SWIR):
    NIR=NIR.astype(int)
    SWIR=SWIR.astype(int)
    NDWI=(NIR-SWIR)/(NIR+SWIR)
    return showImg(NDWI, -1, 1)

# %% [markdown]
# Anwenden auf Fotos

# %%
NDWI(NIR1,SWIR1)

# %%
NDWI(NIR2,SWIR2)

# %%
NDWI(NIR3,SWIR3)
